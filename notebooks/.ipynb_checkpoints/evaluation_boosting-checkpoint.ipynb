# %%
# Out:
# +--------------------------+-------------+-------------------------------------------------+
# | Model                    | Bootstrap   | Files                                           |
# +==========================+=============+=================================================+
# | DenseNet201_SVC          | Bootstrap_9 | models/DenseNet201_SVC_bootstrap_1.pkl          |
# |                          |             | models/DenseNet201_SVC_bootstrap_2.pkl          |
# |                          |             | models/DenseNet201_SVC_bootstrap_3.pkl          |
# |                          |             | models/DenseNet201_SVC_bootstrap_4.pkl          |
# |                          |             | models/DenseNet201_SVC_bootstrap_5.pkl          |
# |                          |             | models/DenseNet201_SVC_bootstrap_6.pkl          |
# |                          |             | models/DenseNet201_SVC_bootstrap_7.pkl          |
# ...
