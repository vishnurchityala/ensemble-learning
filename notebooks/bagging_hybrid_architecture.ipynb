# %%
# !pip install --upgrade numpy
# !pip install --upgrade scipy

# !pip install --upgrade scikit-learn

# !pip install --upgrade tensorflow

# !pip install --upgrade opencv-python
# !pip install --upgrade pandas
# !pip install --upgrade tqdm

# !pip install --upgrade keras
# Out:
# Requirement already satisfied: numpy in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (2.0.2)
# Collecting numpy
#   Using cached numpy-2.2.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Using cached numpy-2.2.3-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.3 which is incompatible.
# numba 0.57.0 requires numpy<1.25,>=1.21, but you have numpy 2.2.3 which is incompatible.
# tensorflow-macos 2.13.0 requires keras<2.14,>=2.13.1, but you have keras 3.8.0 which is incompatible.
# tensorflow-macos 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 2.2.3 which is incompatible.
# tensorflow-macos 2.13.0 requires tensorboard<2.14,>=2.13, but you have tensorboard 2.18.0 which is incompatible.
# Successfully installed numpy-2.2.3
# Requirement already satisfied: scipy in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from scipy) (2.2.3)
# Requirement already satisfied: scikit-learn in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.8.0)
# Collecting numpy<2.1.0,>=1.26.0 (from tensorflow)
#   Using cached numpy-2.0.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: h5py>=3.11.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: rich in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Using cached numpy-2.0.2-cp311-cp311-macosx_14_0_arm64.whl (5.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# numba 0.57.0 requires numpy<1.25,>=1.21, but you have numpy 2.0.2 which is incompatible.
# tensorflow-macos 2.13.0 requires keras<2.14,>=2.13.1, but you have keras 3.8.0 which is incompatible.
# tensorflow-macos 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 2.0.2 which is incompatible.
# tensorflow-macos 2.13.0 requires tensorboard<2.14,>=2.13, but you have tensorboard 2.18.0 which is incompatible.
# Successfully installed numpy-2.0.2
# Requirement already satisfied: opencv-python in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: pandas in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: tqdm in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: keras in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: absl-py in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (0.14.0)
# Requirement already satisfied: ml-dtypes in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from optree->keras) (4.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import cv2
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier


print(f"TensorFlow: {tf.__version__}")
print(f"NumPy: {np.__version__}")
print(f"OpenCV: {cv2.__version__}")
print(f"Pandas: {pd.__version__}")
# Out:
# TensorFlow: 2.18.0
# NumPy: 2.0.2
# OpenCV: 4.11.0
# Pandas: 2.2.3

# %%
def load_model(base_model):
    return tf.keras.applications.__dict__[base_model](
        include_top=False, weights='imagenet', input_shape=(224, 224, 3), pooling='avg'
    )
models = {
    "DenseNet201": load_model("DenseNet201"),
    "InceptionV3": load_model("InceptionV3"),
    "MobileNetV2": load_model("MobileNetV2"),
}

# %%
import numpy as np

def train_hybrid_model(fe_model, classifier_model, X_train, y_train, mask_train=None):
    if mask_train is not None:
        X_train = X_train * mask_train 
    features = fe_model.predict(X_train)
    
    classifier_model.fit(features, y_train)
    
    y_pred = classifier_model.predict(features)
    
    accuracy = accuracy_score(y_train, y_pred)
    precision = precision_score(y_train, y_pred, average='weighted')
    recall = recall_score(y_train, y_pred, average='weighted')
    f1 = f1_score(y_train, y_pred, average='weighted')
    
    return accuracy, precision, recall, f1

# %%
for model_name, model in models.items():
    print(f"Basic Summary for {model_name}:")
    num_params = model.count_params()
    num_layers = len(model.layers)
    print(f"Total Parameters: {num_params}")
    print(f"Number of Layers: {num_layers}")
    print("\n")
# Out:
# Basic Summary for DenseNet201:
# Total Parameters: 18321984
# Number of Layers: 708
#
#
# Basic Summary for InceptionV3:
# Total Parameters: 21802784
# Number of Layers: 312
#
#
# Basic Summary for MobileNetV2:
# Total Parameters: 2257984
# Number of Layers: 155

# %%
def load_ml_model(model_name):
    if model_name == 'SVC':
        return SVC()
    elif model_name == 'KNN':
        return KNeighborsClassifier()
    elif model_name == 'DecisionTree':
        return DecisionTreeClassifier()
    elif model_name == 'MLP':
        return MLPClassifier()
    else:
        raise ValueError(f"Model {model_name} is not defined!")

ml_models = {
    "SVC": load_ml_model("SVC"),
    "KNN": load_ml_model("KNN"),
    "DecisionTree": load_ml_model("DecisionTree"),
    "MLP": load_ml_model("MLP")
}

# %%
for model_name, model in ml_models.items():
    print(f"Parameters for {model_name}:")
    print(model.get_params())
    print("-" * 50)
# Out:
# Parameters for SVC:
# {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# --------------------------------------------------
# Parameters for KNN:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# --------------------------------------------------
# Parameters for DecisionTree:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': None, 'splitter': 'best'}
# --------------------------------------------------
# Parameters for MLP:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': None, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# --------------------------------------------------

# %%
hybrid_architectures = {}

for fe_name, fe_model in models.items():
    for ml_name, ml_model in ml_models.items():
        hybrid_name = f"{fe_name}_{ml_name}"
        hybrid_architectures[hybrid_name] = {
            "Feature Extractor": fe_model,
            "Classifier": ml_model
        }

# %%
count = 0
for hybrid_name, hybrid_model in hybrid_architectures.items():
    count += 1
    print(f"Hybrid Architecture {count}: {hybrid_name}")
    print(f"Feature Extractor: {hybrid_model['Feature Extractor']}")
    print(f"Classifier: {hybrid_model['Classifier']}")
    print("\n")

print(f"Total Hybrid Architectures: {count}")
# Out:
# Hybrid Architecture 1: DenseNet201_SVC
# Feature Extractor: <Functional name=densenet201, built=True>
# Classifier: SVC()
#
#
# Hybrid Architecture 2: DenseNet201_KNN
# Feature Extractor: <Functional name=densenet201, built=True>
# Classifier: KNeighborsClassifier()
#
#
# Hybrid Architecture 3: DenseNet201_DecisionTree
# Feature Extractor: <Functional name=densenet201, built=True>
# Classifier: DecisionTreeClassifier()
#
#
# Hybrid Architecture 4: DenseNet201_MLP
# Feature Extractor: <Functional name=densenet201, built=True>
# Classifier: MLPClassifier()
#
#
# Hybrid Architecture 5: InceptionV3_SVC
# Feature Extractor: <Functional name=inception_v3, built=True>
# Classifier: SVC()
#
#
# Hybrid Architecture 6: InceptionV3_KNN
# Feature Extractor: <Functional name=inception_v3, built=True>
# Classifier: KNeighborsClassifier()
#
#
# Hybrid Architecture 7: InceptionV3_DecisionTree
# Feature Extractor: <Functional name=inception_v3, built=True>
# Classifier: DecisionTreeClassifier()
#
#
# Hybrid Architecture 8: InceptionV3_MLP
# Feature Extractor: <Functional name=inception_v3, built=True>
# Classifier: MLPClassifier()
#
#
# Hybrid Architecture 9: MobileNetV2_SVC
# Feature Extractor: <Functional name=mobilenetv2_1.00_224, built=True>
# Classifier: SVC()
#
#
# Hybrid Architecture 10: MobileNetV2_KNN
# Feature Extractor: <Functional name=mobilenetv2_1.00_224, built=True>
# Classifier: KNeighborsClassifier()
#
#
# Hybrid Architecture 11: MobileNetV2_DecisionTree
# Feature Extractor: <Functional name=mobilenetv2_1.00_224, built=True>
# Classifier: DecisionTreeClassifier()
#
#
# Hybrid Architecture 12: MobileNetV2_MLP
# Feature Extractor: <Functional name=mobilenetv2_1.00_224, built=True>
# Classifier: MLPClassifier()
#
#
# Total Hybrid Architectures: 12

# %%
metadata = pd.read_csv("../augmented_images_details.csv")

# %%
metadata
# Out:
#                                           image_path  \
# 0          ../aug-processed-dataset/benign/aug_1.jpg
# 1          ../aug-processed-dataset/benign/aug_2.jpg
# 2          ../aug-processed-dataset/benign/aug_3.jpg
# 3          ../aug-processed-dataset/benign/aug_4.jpg
# 4          ../aug-processed-dataset/benign/aug_5.jpg
# ...                                              ...
# 2449  ../aug-processed-dataset/malignant/aug_849.jpg
# 2450  ../aug-processed-dataset/malignant/aug_850.jpg
# 2451  ../aug-processed-dataset/malignant/aug_851.jpg
# 2452  ../aug-processed-dataset/malignant/aug_852.jpg
# 2453  ../aug-processed-dataset/malignant/aug_853.jpg
#
#                                               mask_path   category      label  \
# 0        ../aug-processed-dataset/benign/aug_1_mask.png     benign     benign
# 1        ../aug-processed-dataset/benign/aug_2_mask.png     benign     benign
# 2        ../aug-processed-dataset/benign/aug_3_mask.png     benign     benign
# 3        ../aug-processed-dataset/benign/aug_4_mask.png     benign     benign
# 4        ../aug-processed-dataset/benign/aug_5_mask.png     benign     benign
# ...                                                 ...        ...        ...
# 2449  ../aug-processed-dataset/malignant/aug_849_mas...  malignant  malignant
# 2450  ../aug-processed-dataset/malignant/aug_850_mas...  malignant  malignant
# 2451  ../aug-processed-dataset/malignant/aug_851_mas...  malignant  malignant
# 2452  ../aug-processed-dataset/malignant/aug_852_mas...  malignant  malignant
# 2453  ../aug-processed-dataset/malignant/aug_853_mas...  malignant  malignant
#
#       split
# 0     train
# 1       val
# 2     train
# 3     train
# 4     train
# ...     ...
# 2449    val
# 2450  train
# 2451  train
# 2452    val
# 2453  train
#
# [2454 rows x 5 columns]

# %%
metadata.describe()
# Out:
#                                        image_path  \
# count                                        2454
# unique                                       2454
# top     ../aug-processed-dataset/benign/aug_1.jpg
# freq                                            1
#
#                                              mask_path category   label  split
# count                                             2454     2454    2454   2454
# unique                                            2454        3       3      3
# top     ../aug-processed-dataset/benign/aug_1_mask.png   normal  normal  train
# freq                                                 1      907     907   1962

# %%
split_label_counts = metadata.groupby(['split', 'label']).size().reset_index(name='count')

print(split_label_counts)
# Out:
#    split      label  count
# 0   test     benign     69
# 1   test  malignant     85
# 2   test     normal     90
# 3  train     benign    555
# 4  train  malignant    682
# 5  train     normal    725
# 6    val     benign     70
# 7    val  malignant     86
# 8    val     normal     92

# %%
train_data = metadata[metadata['split'] == 'train']
train_data
# Out:
#                                           image_path  \
# 0          ../aug-processed-dataset/benign/aug_1.jpg
# 2          ../aug-processed-dataset/benign/aug_3.jpg
# 3          ../aug-processed-dataset/benign/aug_4.jpg
# 4          ../aug-processed-dataset/benign/aug_5.jpg
# 5          ../aug-processed-dataset/benign/aug_6.jpg
# ...                                              ...
# 2446  ../aug-processed-dataset/malignant/aug_846.jpg
# 2447  ../aug-processed-dataset/malignant/aug_847.jpg
# 2450  ../aug-processed-dataset/malignant/aug_850.jpg
# 2451  ../aug-processed-dataset/malignant/aug_851.jpg
# 2453  ../aug-processed-dataset/malignant/aug_853.jpg
#
#                                               mask_path   category      label  \
# 0        ../aug-processed-dataset/benign/aug_1_mask.png     benign     benign
# 2        ../aug-processed-dataset/benign/aug_3_mask.png     benign     benign
# 3        ../aug-processed-dataset/benign/aug_4_mask.png     benign     benign
# 4        ../aug-processed-dataset/benign/aug_5_mask.png     benign     benign
# 5        ../aug-processed-dataset/benign/aug_6_mask.png     benign     benign
# ...                                                 ...        ...        ...
# 2446  ../aug-processed-dataset/malignant/aug_846_mas...  malignant  malignant
# 2447  ../aug-processed-dataset/malignant/aug_847_mas...  malignant  malignant
# 2450  ../aug-processed-dataset/malignant/aug_850_mas...  malignant  malignant
# 2451  ../aug-processed-dataset/malignant/aug_851_mas...  malignant  malignant
# 2453  ../aug-processed-dataset/malignant/aug_853_mas...  malignant  malignant
#
#       split
# 0     train
# 2     train
# 3     train
# 4     train
# 5     train
# ...     ...
# 2446  train
# 2447  train
# 2450  train
# 2451  train
# 2453  train
#
# [1962 rows x 5 columns]

# %%
test_data = metadata[metadata['split'] == 'test']
test_data
# Out:
#                                           image_path  \
# 9         ../aug-processed-dataset/benign/aug_10.jpg
# 35        ../aug-processed-dataset/benign/aug_36.jpg
# 42        ../aug-processed-dataset/benign/aug_43.jpg
# 51        ../aug-processed-dataset/benign/aug_52.jpg
# 68        ../aug-processed-dataset/benign/aug_69.jpg
# ...                                              ...
# 2410  ../aug-processed-dataset/malignant/aug_810.jpg
# 2428  ../aug-processed-dataset/malignant/aug_828.jpg
# 2437  ../aug-processed-dataset/malignant/aug_837.jpg
# 2443  ../aug-processed-dataset/malignant/aug_843.jpg
# 2448  ../aug-processed-dataset/malignant/aug_848.jpg
#
#                                               mask_path   category      label  \
# 9       ../aug-processed-dataset/benign/aug_10_mask.png     benign     benign
# 35      ../aug-processed-dataset/benign/aug_36_mask.png     benign     benign
# 42      ../aug-processed-dataset/benign/aug_43_mask.png     benign     benign
# 51      ../aug-processed-dataset/benign/aug_52_mask.png     benign     benign
# 68      ../aug-processed-dataset/benign/aug_69_mask.png     benign     benign
# ...                                                 ...        ...        ...
# 2410  ../aug-processed-dataset/malignant/aug_810_mas...  malignant  malignant
# 2428  ../aug-processed-dataset/malignant/aug_828_mas...  malignant  malignant
# 2437  ../aug-processed-dataset/malignant/aug_837_mas...  malignant  malignant
# 2443  ../aug-processed-dataset/malignant/aug_843_mas...  malignant  malignant
# 2448  ../aug-processed-dataset/malignant/aug_848_mas...  malignant  malignant
#
#      split
# 9     test
# 35    test
# 42    test
# 51    test
# 68    test
# ...    ...
# 2410  test
# 2428  test
# 2437  test
# 2443  test
# 2448  test
#
# [244 rows x 5 columns]

# %%
def load_image(image_path, target_size=(224, 224)):
    image = tf.io.read_file(image_path) 
    image = tf.image.decode_png(image, channels=3)
    image = tf.image.resize(image, target_size)
    image = image / 255.0 
    return image

def load_mask(mask_path, target_size=(224, 224)):
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, target_size) 
    mask = mask / 255.0
    return mask

X_train = np.array([load_image(image_path) for image_path in train_data['image_path']])
mask_train = np.array([load_mask(mask_path) for mask_path in train_data['mask_path']])
y_train = train_data['label'].values

print("Training data shapes:")
print(f"X_train: {X_train.shape}")
print(f"mask_train: {mask_train.shape}")
print(f"y_train: {y_train.shape}")

X_test = np.array([load_image(image_path) for image_path in test_data['image_path']])
mask_test = np.array([load_mask(mask_path) for mask_path in test_data['mask_path']])
y_test = test_data['label'].values

print("\nTesting data shapes:")
print(f"X_test: {X_test.shape}")
print(f"mask_test: {mask_test.shape}")
print(f"y_test: {y_test.shape}")

print("\nData ranges:")
print(f"X_train min: {np.min(X_train)}, max: {np.max(X_train)}")
print(f"mask_train min: {np.min(mask_train)}, max: {np.max(mask_train)}")
print(f"X_test min: {np.min(X_test)}, max: {np.max(X_test)}")
print(f"mask_test min: {np.min(mask_test)}, max: {np.max(mask_test)}")

print("\nClass distribution:")
print("Training labels:", np.unique(y_train, return_counts=True))
print("Testing labels:", np.unique(y_test, return_counts=True))
# Out:
# Training data shapes:
# X_train: (1962, 224, 224, 3)
# mask_train: (1962, 224, 224, 1)
# y_train: (1962,)
#
# Testing data shapes:
# X_test: (244, 224, 224, 3)
# mask_test: (244, 224, 224, 1)
# y_test: (244,)
#
# Data ranges:
# X_train min: 0.0, max: 1.0
# mask_train min: 0.0, max: 1.0
# X_test min: 0.0, max: 1.0
# mask_test min: 0.0, max: 1.0
#
# Class distribution:
# Training labels: (array(['benign', 'malignant', 'normal'], dtype=object), array([555, 682, 725]))
# Testing labels: (array(['benign', 'malignant', 'normal'], dtype=object), array([69, 85, 90]))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

ensemble_results = {}

estimator_counts = [3, 5, 7, 9]

for hybrid_name, hybrid_model in hybrid_architectures.items():
    print(f"\nEvaluating Hybrid Architecture: {hybrid_name}")
    
    fe_model = hybrid_model['Feature Extractor']
    ml_model = hybrid_model['Classifier']
    
    X_train_features = fe_model.predict(X_train)
    X_test_features = fe_model.predict(X_test)
    
    hybrid_ensemble_results = {}
    
    for n_estimators in estimator_counts:
        print(f"\nEvaluating Bagging Ensemble with {n_estimators} estimators:")
        
        bagging = BaggingClassifier(
            estimator=ml_model,
            n_estimators=n_estimators,
            max_samples=0.6,
            bootstrap=False,
            random_state=42
        )
        
        bagging.fit(X_train_features, y_train)
        
        ensemble_pred = bagging.predict(X_test_features)
        
        ensemble_accuracy = accuracy_score(y_test, ensemble_pred)
        ensemble_precision = precision_score(y_test, ensemble_pred, average='weighted')
        ensemble_recall = recall_score(y_test, ensemble_pred, average='weighted')
        ensemble_f1 = f1_score(y_test, ensemble_pred, average='weighted')
        
        hybrid_ensemble_results[f'Ensemble_{n_estimators}'] = {
            "Accuracy": ensemble_accuracy,
            "Precision": ensemble_precision,
            "Recall": ensemble_recall,
            "F1 Score": ensemble_f1
        }
        
        print(f"Ensemble with {n_estimators} estimators - "
              f"Accuracy: {ensemble_accuracy:.4f}, Precision: {ensemble_precision:.4f}, "
              f"Recall: {ensemble_recall:.4f}, F1 Score: {ensemble_f1:.4f}")
    
    ensemble_results[hybrid_name] = hybrid_ensemble_results

print("\n\n===== RESULTS SUMMARY =====")
print("Hybrid Architecture | 3 Estimators | 5 Estimators | 7 Estimators | 9 Estimators")
print("-" * 70)

for hybrid_name, results in ensemble_results.items():
    acc_3 = results['Ensemble_3']['Accuracy'] * 100
    acc_5 = results['Ensemble_5']['Accuracy'] * 100
    acc_7 = results['Ensemble_7']['Accuracy'] * 100
    acc_9 = results['Ensemble_9']['Accuracy'] * 100
    
    print(f"{hybrid_name:20} | {acc_3:11.2f}% | {acc_5:11.2f}% | {acc_7:11.2f}% | {acc_9:11.2f}%")
# Out:
# Evaluating Hybrid Architecture: DenseNet201_SVC
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.7377, Precision: 0.7361, Recall: 0.7377, F1 Score: 0.7306
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.7459, Precision: 0.7488, Recall: 0.7459, F1 Score: 0.7382
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.7459, Precision: 0.7538, Recall: 0.7459, F1 Score: 0.7374
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.7500, Precision: 0.7565, Recall: 0.7500, F1 Score: 0.7423
#
# Evaluating Hybrid Architecture: DenseNet201_KNN
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.6762, Precision: 0.6784, Recall: 0.6762, F1 Score: 0.6622
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.6721, Precision: 0.6804, Recall: 0.6721, F1 Score: 0.6584
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.6721, Precision: 0.6857, Recall: 0.6721, F1 Score: 0.6558
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.6598, Precision: 0.6800, Recall: 0.6598, F1 Score: 0.6428
#
# Evaluating Hybrid Architecture: DenseNet201_DecisionTree
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.5984, Precision: 0.6128, Recall: 0.5984, F1 Score: 0.6027
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.6025, Precision: 0.6154, Recall: 0.6025, F1 Score: 0.6057
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.6107, Precision: 0.6101, Recall: 0.6107, F1 Score: 0.6104
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.6393, Precision: 0.6382, Recall: 0.6393, F1 Score: 0.6386
#
# Evaluating Hybrid Architecture: DenseNet201_MLP
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 3 estimators - Accuracy: 0.7377, Precision: 0.7352, Recall: 0.7377, F1 Score: 0.7349
#
# Evaluating Bagging Ensemble with 5 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 5 estimators - Accuracy: 0.7500, Precision: 0.7469, Recall: 0.7500, F1 Score: 0.7462
#
# Evaluating Bagging Ensemble with 7 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 7 estimators - Accuracy: 0.7582, Precision: 0.7554, Recall: 0.7582, F1 Score: 0.7542
#
# Evaluating Bagging Ensemble with 9 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 9 estimators - Accuracy: 0.7582, Precision: 0.7562, Recall: 0.7582, F1 Score: 0.7541
#
# Evaluating Hybrid Architecture: InceptionV3_SVC
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 51s 827ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 687ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.6885, Precision: 0.6926, Recall: 0.6885, F1 Score: 0.6821
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.7008, Precision: 0.7147, Recall: 0.7008, F1 Score: 0.6924
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.6926, Precision: 0.7024, Recall: 0.6926, F1 Score: 0.6853
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.6844, Precision: 0.6922, Recall: 0.6844, F1 Score: 0.6771
#
# Evaluating Hybrid Architecture: InceptionV3_KNN
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 51s 821ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 829ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.6434, Precision: 0.6486, Recall: 0.6434, F1 Score: 0.6384
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.6434, Precision: 0.6583, Recall: 0.6434, F1 Score: 0.6336
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.6189, Precision: 0.6347, Recall: 0.6189, F1 Score: 0.6055
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.6148, Precision: 0.6346, Recall: 0.6148, F1 Score: 0.6004
#
# Evaluating Hybrid Architecture: InceptionV3_DecisionTree
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 49s 792ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 470ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.5451, Precision: 0.5545, Recall: 0.5451, F1 Score: 0.5458
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.5410, Precision: 0.5442, Recall: 0.5410, F1 Score: 0.5424
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.5738, Precision: 0.5728, Recall: 0.5738, F1 Score: 0.5728
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.6311, Precision: 0.6318, Recall: 0.6311, F1 Score: 0.6309
#
# Evaluating Hybrid Architecture: InceptionV3_MLP
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 38s 611ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 456ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 3 estimators - Accuracy: 0.7295, Precision: 0.7277, Recall: 0.7295, F1 Score: 0.7283
#
# Evaluating Bagging Ensemble with 5 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 5 estimators - Accuracy: 0.7541, Precision: 0.7526, Recall: 0.7541, F1 Score: 0.7519
#
# Evaluating Bagging Ensemble with 7 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 7 estimators - Accuracy: 0.7582, Precision: 0.7582, Recall: 0.7582, F1 Score: 0.7554
#
# Evaluating Bagging Ensemble with 9 estimators:
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vishnurchityala/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble with 9 estimators - Accuracy: 0.7623, Precision: 0.7625, Recall: 0.7623, F1 Score: 0.7598
#
# Evaluating Hybrid Architecture: MobileNetV2_SVC
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 17s 275ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.7459, Precision: 0.7411, Recall: 0.7459, F1 Score: 0.7370
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.7623, Precision: 0.7609, Recall: 0.7623, F1 Score: 0.7534
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.7623, Precision: 0.7606, Recall: 0.7623, F1 Score: 0.7534
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.7582, Precision: 0.7569, Recall: 0.7582, F1 Score: 0.7496
#
# Evaluating Hybrid Architecture: MobileNetV2_KNN
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.6885, Precision: 0.6827, Recall: 0.6885, F1 Score: 0.6661
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.6803, Precision: 0.6757, Recall: 0.6803, F1 Score: 0.6547
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.7008, Precision: 0.7090, Recall: 0.7008, F1 Score: 0.6788
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.6885, Precision: 0.6863, Recall: 0.6885, F1 Score: 0.6620
#
# Evaluating Hybrid Architecture: MobileNetV2_DecisionTree
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.5492, Precision: 0.5563, Recall: 0.5492, F1 Score: 0.5518
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.5984, Precision: 0.6042, Recall: 0.5984, F1 Score: 0.5987
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.6434, Precision: 0.6429, Recall: 0.6434, F1 Score: 0.6408
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.6434, Precision: 0.6415, Recall: 0.6434, F1 Score: 0.6401
#
# Evaluating Hybrid Architecture: MobileNetV2_MLP
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step
#
# Evaluating Bagging Ensemble with 3 estimators:
# Ensemble with 3 estimators - Accuracy: 0.7951, Precision: 0.7931, Recall: 0.7951, F1 Score: 0.7923
#
# Evaluating Bagging Ensemble with 5 estimators:
# Ensemble with 5 estimators - Accuracy: 0.7910, Precision: 0.7885, Recall: 0.7910, F1 Score: 0.7872
#
# Evaluating Bagging Ensemble with 7 estimators:
# Ensemble with 7 estimators - Accuracy: 0.7992, Precision: 0.7969, Recall: 0.7992, F1 Score: 0.7951
#
# Evaluating Bagging Ensemble with 9 estimators:
# Ensemble with 9 estimators - Accuracy: 0.7992, Precision: 0.7974, Recall: 0.7992, F1 Score: 0.7957
#
#
# ===== RESULTS SUMMARY =====
# Hybrid Architecture | 3 Estimators | 5 Estimators | 7 Estimators | 9 Estimators
# ----------------------------------------------------------------------
# DenseNet201_SVC      |       73.77% |       74.59% |       74.59% |       75.00%
# DenseNet201_KNN      |       67.62% |       67.21% |       67.21% |       65.98%
# DenseNet201_DecisionTree |       59.84% |       60.25% |       61.07% |       63.93%
# DenseNet201_MLP      |       73.77% |       75.00% |       75.82% |       75.82%
# InceptionV3_SVC      |       68.85% |       70.08% |       69.26% |       68.44%
# InceptionV3_KNN      |       64.34% |       64.34% |       61.89% |       61.48%
# InceptionV3_DecisionTree |       54.51% |       54.10% |       57.38% |       63.11%
# InceptionV3_MLP      |       72.95% |       75.41% |       75.82% |       76.23%
# MobileNetV2_SVC      |       74.59% |       76.23% |       76.23% |       75.82%
# MobileNetV2_KNN      |       68.85% |       68.03% |       70.08% |       68.85%
# MobileNetV2_DecisionTree |       54.92% |       59.84% |       64.34% |       64.34%
# MobileNetV2_MLP      |       79.51% |       79.10% |       79.92% |       79.92%

# %%
print("\n\n===== RESULTS SUMMARY =====")
print("Hybrid Architecture       | 3 Estimators | 5 Estimators | 7 Estimators | 9 Estimators")
print("-" * 80)

for hybrid_name, results in ensemble_results.items():
    acc_3 = results['Ensemble_3']['Accuracy'] * 100
    acc_5 = results['Ensemble_5']['Accuracy'] * 100
    acc_7 = results['Ensemble_7']['Accuracy'] * 100
    acc_9 = results['Ensemble_9']['Accuracy'] * 100
    
    print(f"{hybrid_name:25} | {acc_3:12.2f}% | {acc_5:12.2f}% | {acc_7:12.2f}% | {acc_9:12.2f}%")
# Out:
# ===== RESULTS SUMMARY =====
# Hybrid Architecture       | 3 Estimators | 5 Estimators | 7 Estimators | 9 Estimators
# --------------------------------------------------------------------------------
# DenseNet201_SVC           |        73.77% |        74.59% |        74.59% |        75.00%
# DenseNet201_KNN           |        67.62% |        67.21% |        67.21% |        65.98%
# DenseNet201_DecisionTree  |        59.84% |        60.25% |        61.07% |        63.93%
# DenseNet201_MLP           |        73.77% |        75.00% |        75.82% |        75.82%
# InceptionV3_SVC           |        68.85% |        70.08% |        69.26% |        68.44%
# InceptionV3_KNN           |        64.34% |        64.34% |        61.89% |        61.48%
# InceptionV3_DecisionTree  |        54.51% |        54.10% |        57.38% |        63.11%
# InceptionV3_MLP           |        72.95% |        75.41% |        75.82% |        76.23%
# MobileNetV2_SVC           |        74.59% |        76.23% |        76.23% |        75.82%
# MobileNetV2_KNN           |        68.85% |        68.03% |        70.08% |        68.85%
# MobileNetV2_DecisionTree  |        54.92% |        59.84% |        64.34% |        64.34%
# MobileNetV2_MLP           |        79.51% |        79.10% |        79.92% |        79.92%
